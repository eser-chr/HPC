# %%
import numpy as np
import matplotlib.pyplot as plt
import game
from scipy.signal import convolve2d

# %%
A = np.zeros((5,5)).astype(bool)
A[0,0]=True
A[2,0]=True
A[4,0]=True

A[2,3]=True

A[1,2]=True
A[1,3]=True

A[4,2]=True
A[4,4]=True
plt.imshow(A, cmap="grey")

# %%
N=M=1024

input = game.init(N*M, 50)
output = input.copy()

# %%
output = game.py_run_sim(output, N, 100)

# %%
plt.imshow(input.reshape((N,M)), cmap="grey")

# %%
plt.imshow(output.reshape((N,M))[2:-2,2:-2], cmap="grey")
